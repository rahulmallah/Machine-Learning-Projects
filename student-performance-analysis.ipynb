# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
data=pd.read_csv('../input/students-performance-in-exams/StudentsPerformance.csv')

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
import warnings
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
sns.countplot(data['gender'])
plt.title('GENDER')
plt.show()

# %%
sns.countplot(data['race/ethnicity'])
plt.xticks(rotation=45)
plt.show()

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
sns.countplot(data['parental level of education'])
plt.xticks(rotation=50)
plt.show()

# %%
data['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
data['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
sns.distplot(data['math score'])
plt.show()

# %%
sns.distplot(data['reading score'],color='olive')
plt.show()

# %%
sns.distplot(data['writing score'],color='green')
plt.show()

# %%
sns.jointplot(x='math score',y='reading score',data=data,kind='reg')
plt.show()

# %%
sns.jointplot(x='math score',y='writing score',data=data,color='orange',kind='reg')
plt.show()

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, projection = '3d')

x = data['math score']
y = data['reading score']
z = data['writing score']

ax.set_xlabel("math score of the students")
ax.set_ylabel("reading score of the students")
ax.set_zlabel("writing score of the students")

ax.scatter(x, y, z)

plt.show()

# %%
sns.jointplot(x='math score',y='reading score',hue='gender',data=data,color='olive')
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.jointplot(x='math score',y='writing score',data=data,hue='parental level of education')
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.jointplot(x='math score',y='reading score',hue='race/ethnicity',data=data)
plt.show()

# %%
sns.jointplot(x='reading score',y='writing score',data=data,hue='test preparation course')
plt.figure(figsize=(15,14))
plt.show()

# %%
sns.scatterplot(x='math score',y='writing score',data=data,hue='lunch')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='parental level of education',y='math score',hue='test preparation course',data=data)
plt.xticks(rotation=51)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='parental level of education',y='math score',hue='gender',data=data)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.barplot(x='parental level of education',y='writing score',hue='gender',data=data)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.barplot(x='lunch',y='reading score',data=data,hue='gender')
plt.xticks(rotation=45)
plt.show()

# %%
data.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
sns.heatmap(data.corr(),annot=True,cmap='BuPu')
plt.show()
